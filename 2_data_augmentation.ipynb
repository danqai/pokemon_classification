# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dropout, Dense, Activation
from tensorflow.keras.layers import BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras import regularizers
from tensorflow.keras.applications import Xception
from tensorflow.keras import Input, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import matplotlib.image as mig
import numpy as np
import pathlib
np.random.seed(69)

# %% [markdown]
# **DEFINING CLASS**

# %%
PATH = './PokemonData/'
data_dir = pathlib.Path(PATH)

# %%
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"])
CLASS_NAMES.shape
# Out:
# (151,)

# %%
IDG_train = ImageDataGenerator(rescale = 1./255,
                               validation_split=0.2,
                               horizontal_flip=True,
                               zoom_range=0.1,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               rotation_range=60,
                               channel_shift_range=69)

IDG_valid = ImageDataGenerator(rescale = 1./255,
                               validation_split=0.2)

train_data = IDG_train.flow_from_directory(PATH,
                                           target_size=(299, 299),
                                           batch_size=32,
                                           classes = list(CLASS_NAMES),
                                           subset='training',
                                           shuffle=True,
                                           seed=69)

validation_data = IDG_valid.flow_from_directory(PATH,
                                                target_size=(299, 299),
                                                batch_size=32,
                                                classes = list(CLASS_NAMES),
                                                subset='validation',
                                                shuffle=False,
                                                seed=69)
# Out:
# Found 5542 images belonging to 151 classes.
# Found 1311 images belonging to 151 classes.

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image_batch[n])
      plt.title(CLASS_NAMES[label_batch[n].argmax()])
      plt.axis('off')

# %%
image_batch, label_batch = train_data[0]
show_batch(image_batch, label_batch)

# %%
base_model = Xception(weights='imagenet',  # Load weights pre-trained on ImageNet.
                 input_shape=(299, 299, 3),
                 include_top=False)  # Do not include the ImageNet classifier at the top.
base_model.trainable = False
inputs = Input(shape=(299, 299, 3))
# We make sure that the base_model is running in inference mode here,
# by passing `training=False`. This is important for fine-tuning, as you will
# learn in a few paragraphs.
x = base_model(inputs, training=False)
# Convert features of shape `base_model.output_shape[1:]` to vectors
x = GlobalAveragePooling2D()(x)
# A Dense classifier with a single unit (binary classification)
outputs = Dense(CLASS_NAMES.shape[0], activation='softmax')(x)
model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 299, 299, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 151)               309399
# =================================================================
# Total params: 21,170,879
# Trainable params: 309,399
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy'])

hist = model.fit(train_data, epochs=50, steps_per_epoch = len(train_data), validation_data=validation_data, validation_steps=len(validation_data))
# Out:
# Epoch 1/50
# 174/174 [==============================] - 110s 634ms/step - loss: 4.1158 - accuracy: 0.2135 - val_loss: 3.3017 - val_accuracy: 0.3745
# Epoch 2/50
# 174/174 [==============================] - 110s 630ms/step - loss: 2.5735 - accuracy: 0.5361 - val_loss: 2.5546 - val_accuracy: 0.5065
# Epoch 3/50
# 174/174 [==============================] - 102s 588ms/step - loss: 1.8935 - accuracy: 0.6711 - val_loss: 2.1864 - val_accuracy: 0.5637
# Epoch 4/50
# 174/174 [==============================] - 102s 585ms/step - loss: 1.5329 - accuracy: 0.7274 - val_loss: 1.9628 - val_accuracy: 0.6026
# Epoch 5/50
# 174/174 [==============================] - 101s 583ms/step - loss: 1.2847 - accuracy: 0.7703 - val_loss: 1.8194 - val_accuracy: 0.5995
# Epoch 6/50
# 174/174 [==============================] - 101s 582ms/step - loss: 1.1113 - accuracy: 0.7941 - val_loss: 1.7008 - val_accuracy: 0.6262
# Epoch 7/50
# 174/174 [==============================] - 101s 582ms/step - loss: 0.9746 - accuracy: 0.8237 - val_loss: 1.6264 - val_accuracy: 0.6522
# Epoch 8/50
# 174/174 [==============================] - 101s 582ms/step - loss: 0.8823 - accuracy: 0.8385 - val_loss: 1.5676 - val_accuracy: 0.6453
# Epoch 9/50
# 174/174 [==============================] - 101s 583ms/step - loss: 0.7855 - accuracy: 0.8607 - val_loss: 1.5146 - val_accuracy: 0.6476
# Epoch 10/50
# 174/174 [==============================] - 101s 583ms/step - loss: 0.7218 - accuracy: 0.8728 - val_loss: 1.4815 - val_accuracy: 0.6522
# Epoch 11/50
# 174/174 [==============================] - 101s 582ms/step - loss: 0.6542 - accuracy: 0.8836 - val_loss: 1.4428 - val_accuracy: 0.6751
# Epoch 12/50
# 174/174 [==============================] - 101s 582ms/step - loss: 0.5950 - accuracy: 0.8926 - val_loss: 1.4049 - val_accuracy: 0.6789
# Epoch 13/50
# 174/174 [==============================] - 101s 582ms/step - loss: 0.5439 - accuracy: 0.9053 - val_loss: 1.3700 - val_accuracy: 0.6796
# Epoch 14/50
# 174/174 [==============================] - 102s 584ms/step - loss: 0.5151 - accuracy: 0.9087 - val_loss: 1.3650 - val_accuracy: 0.6789
# Epoch 15/50
# 174/174 [==============================] - 101s 582ms/step - loss: 0.4856 - accuracy: 0.9161 - val_loss: 1.3490 - val_accuracy: 0.6728
# Epoch 16/50
# 174/174 [==============================] - 101s 582ms/step - loss: 0.4570 - accuracy: 0.9235 - val_loss: 1.3166 - val_accuracy: 0.6773
# Epoch 17/50
# 174/174 [==============================] - 101s 581ms/step - loss: 0.4383 - accuracy: 0.9211 - val_loss: 1.3165 - val_accuracy: 0.6911
# Epoch 18/50
# 174/174 [==============================] - 101s 580ms/step - loss: 0.3947 - accuracy: 0.9365 - val_loss: 1.3036 - val_accuracy: 0.6888
# Epoch 19/50
# 174/174 [==============================] - 101s 580ms/step - loss: 0.3805 - accuracy: 0.9368 - val_loss: 1.2893 - val_accuracy: 0.6895
# Epoch 20/50
# 174/174 [==============================] - 101s 580ms/step - loss: 0.3411 - accuracy: 0.9446 - val_loss: 1.2763 - val_accuracy: 0.6918
# Epoch 21/50
# 174/174 [==============================] - 104s 595ms/step - loss: 0.3400 - accuracy: 0.9453 - val_loss: 1.2857 - val_accuracy: 0.6934
# Epoch 22/50
# 174/174 [==============================] - 104s 598ms/step - loss: 0.3122 - accuracy: 0.9493 - val_loss: 1.2505 - val_accuracy: 0.7010
# Epoch 23/50
# 174/174 [==============================] - 102s 585ms/step - loss: 0.3069 - accuracy: 0.9457 - val_loss: 1.2399 - val_accuracy: 0.7010
# Epoch 24/50
# 174/174 [==============================] - 102s 584ms/step - loss: 0.2882 - accuracy: 0.9524 - val_loss: 1.2445 - val_accuracy: 0.6911
# Epoch 25/50
# 174/174 [==============================] - 102s 587ms/step - loss: 0.2746 - accuracy: 0.9567 - val_loss: 1.2209 - val_accuracy: 0.6957
# Epoch 26/50
# 174/174 [==============================] - 102s 589ms/step - loss: 0.2641 - accuracy: 0.9549 - val_loss: 1.2258 - val_accuracy: 0.7040
# Epoch 27/50
# 174/174 [==============================] - 102s 587ms/step - loss: 0.2557 - accuracy: 0.9589 - val_loss: 1.2119 - val_accuracy: 0.7025
# Epoch 28/50
# 174/174 [==============================] - 102s 585ms/step - loss: 0.2354 - accuracy: 0.9625 - val_loss: 1.2211 - val_accuracy: 0.6972
# Epoch 29/50
# 174/174 [==============================] - 102s 585ms/step - loss: 0.2288 - accuracy: 0.9608 - val_loss: 1.2013 - val_accuracy: 0.7033
# Epoch 30/50
# 174/174 [==============================] - 102s 586ms/step - loss: 0.2146 - accuracy: 0.9717 - val_loss: 1.2274 - val_accuracy: 0.7002
# Epoch 31/50
# 174/174 [==============================] - 103s 589ms/step - loss: 0.2097 - accuracy: 0.9668 - val_loss: 1.2185 - val_accuracy: 0.6979
# Epoch 32/50
# 174/174 [==============================] - 110s 630ms/step - loss: 0.2005 - accuracy: 0.9709 - val_loss: 1.2150 - val_accuracy: 0.7025
# Epoch 33/50
# 174/174 [==============================] - 110s 630ms/step - loss: 0.1905 - accuracy: 0.9702 - val_loss: 1.1909 - val_accuracy: 0.7063
# Epoch 34/50
# 174/174 [==============================] - 109s 624ms/step - loss: 0.1798 - accuracy: 0.9722 - val_loss: 1.1824 - val_accuracy: 0.7079
# Epoch 35/50
# 174/174 [==============================] - 108s 623ms/step - loss: 0.1746 - accuracy: 0.9693 - val_loss: 1.1806 - val_accuracy: 0.7101
# Epoch 36/50
# 174/174 [==============================] - 108s 622ms/step - loss: 0.1750 - accuracy: 0.9704 - val_loss: 1.1929 - val_accuracy: 0.7094
# Epoch 37/50
# 174/174 [==============================] - 108s 622ms/step - loss: 0.1637 - accuracy: 0.9746 - val_loss: 1.1915 - val_accuracy: 0.7101
# Epoch 38/50
# 174/174 [==============================] - 108s 621ms/step - loss: 0.1590 - accuracy: 0.9760 - val_loss: 1.1931 - val_accuracy: 0.7033
# Epoch 39/50
# 174/174 [==============================] - 108s 622ms/step - loss: 0.1474 - accuracy: 0.9794 - val_loss: 1.1809 - val_accuracy: 0.7185
# Epoch 40/50
# 174/174 [==============================] - 109s 626ms/step - loss: 0.1479 - accuracy: 0.9758 - val_loss: 1.1785 - val_accuracy: 0.7185
# Epoch 41/50
# 174/174 [==============================] - 108s 620ms/step - loss: 0.1415 - accuracy: 0.9789 - val_loss: 1.1787 - val_accuracy: 0.7071
# Epoch 42/50
# 174/174 [==============================] - 108s 621ms/step - loss: 0.1421 - accuracy: 0.9765 - val_loss: 1.1984 - val_accuracy: 0.7056
# Epoch 43/50
# 174/174 [==============================] - 108s 618ms/step - loss: 0.1418 - accuracy: 0.9785 - val_loss: 1.1851 - val_accuracy: 0.7079
# Epoch 44/50
# 174/174 [==============================] - 110s 631ms/step - loss: 0.1273 - accuracy: 0.9773 - val_loss: 1.1627 - val_accuracy: 0.7208
# Epoch 45/50
# 174/174 [==============================] - 109s 628ms/step - loss: 0.1253 - accuracy: 0.9809 - val_loss: 1.1785 - val_accuracy: 0.7086
# Epoch 46/50
# 174/174 [==============================] - 109s 626ms/step - loss: 0.1250 - accuracy: 0.9802 - val_loss: 1.1821 - val_accuracy: 0.7071
# Epoch 47/50
# 174/174 [==============================] - 109s 628ms/step - loss: 0.1145 - accuracy: 0.9787 - val_loss: 1.1912 - val_accuracy: 0.7170
# Epoch 48/50
# 174/174 [==============================] - 109s 626ms/step - loss: 0.1174 - accuracy: 0.9829 - val_loss: 1.1802 - val_accuracy: 0.7124
# Epoch 49/50
# 174/174 [==============================] - 109s 627ms/step - loss: 0.1121 - accuracy: 0.9820 - val_loss: 1.1905 - val_accuracy: 0.7201
# Epoch 50/50
# 174/174 [==============================] - 109s 627ms/step - loss: 0.1092 - accuracy: 0.9820 - val_loss: 1.1802 - val_accuracy: 0.7170

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(14,14))
plt.plot(hist.history['accuracy'],label='accuracy',color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.yticks(np.arange(0, 1, step=0.04))
plt.show()

# %%
plt.figure(figsize=(20,20))
sam_x = []
sam_y = []
for i in np.random.choice(len(validation_data), size=16, replace=False):
    x, y = validation_data[i]
    sam_x.append(x[0])
    sam_y.append(y[0])
sam_x = np.array(sam_x)
pred_ = model.predict(sam_x)
for i in range(16):
    pred,y = pred_[i].argmax(), sam_y[i].argmax()
    plt.subplot(4,4,i+1)
    plt.imshow(sam_x[i])
    title_ = 'Predict:' + str(CLASS_NAMES[pred])+ ';   Label:' + str(CLASS_NAMES[y])
    plt.title(title_,size=11)
plt.show()

# %%
y_true = validation_data.labels
y_pred = model.predict(validation_data).argmax(axis=1)
c = confusion_matrix(y_true, y_pred)

# %%
plt.figure(figsize=(20,20))
plt.imshow(c)
plt.colorbar()
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion matrix')
# Out:
# Text(0.5, 1.0, 'Confusion matrix')

# %%
plt.figure(figsize=(20,40))
plt.barh(CLASS_NAMES, c.diagonal() / c.sum(axis=1))
plt.ylabel('Pokemon')
plt.xlabel('Fraction correctly labeled')
# Out:
# Text(0.5, 0, 'Fraction correctly labeled')
